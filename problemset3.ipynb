# %% [markdown]
# #Question 1 Answers

# %%
#Step 1
import numpy as np
import pandas as pd

# %%
#Step 2

dataSet1 = pd.read_csv(r'C:\Users\aryas\Documents\datas.csv')

# %%
dataSet1.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
#Step 4
(dataSet1.groupby('occupation').mean()['age'])
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
#Step 5
count1=dataSet1[dataSet1['gender']=='M'].groupby('occupation').count()['gender']
count2=dataSet1.groupby('occupation').count()['gender']
maleRatio=(count1/count2)*100
maleRatio.sort_values(ascending=False)
# Out:
# occupation
# doctor           100.000000
# engineer          97.014925
# technician        96.296296
# retired           92.857143
# programmer        90.909091
# executive         90.625000
# scientist         90.322581
# entertainment     88.888889
# lawyer            83.333333
# salesman          75.000000
# educator          72.631579
# student           69.387755
# other             65.714286
# marketing         61.538462
# writer            57.777778
# none              55.555556
# administrator     54.430380
# artist            53.571429
# librarian         43.137255
# healthcare        31.250000
# homemaker         14.285714
# Name: gender, dtype: float64

# %%
#Step 6
dataSet1.groupby('occupation').age.agg([min,max])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %%
#step 7
dataSet1.groupby(['occupation','gender']).mean()['age']
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %%
#Step 8
women=dataSet1[dataSet1['gender']=='F'].groupby('occupation').count()['gender']
total=dataSet1.groupby('occupation').count()['gender']
perctg=pd.DataFrame((women/total)*100)
perctg.columns=['F']
perctg['M']=r['M']
perctg
# Out:
#                        F           M
# occupation
# administrator  45.569620   54.430380
# artist         46.428571   53.571429
# doctor               NaN  100.000000
# educator       27.368421   72.631579
# engineer        2.985075   97.014925
# entertainment  11.111111   88.888889
# executive       9.375000   90.625000
# healthcare     68.750000   31.250000
# homemaker      85.714286   14.285714
# lawyer         16.666667   83.333333
# librarian      56.862745   43.137255
# marketing      38.461538   61.538462
# none           44.444444   55.555556
# other          34.285714   65.714286
# programmer      9.090909   90.909091
# retired         7.142857   92.857143
# salesman       25.000000   75.000000
# scientist       9.677419   90.322581
# student        30.612245   69.387755
# technician      3.703704   96.296296
# writer         42.222222   57.777778

# %% [markdown]
# #Question 2

# %%
#Step 1
euro12=pd.read_csv(r'C:\Users\aryas\Documents\teams.csv')

# %%
euro12.head()
# Out:
#              Team  Goals  Shots on target  Shots off target  \
# 0         Croatia      4               13                12
# 1  Czech Republic      4               13                18
# 2         Denmark      4               10                10
# 3         England      5               11                18
# 4          France      3               22                24
#
#    Shooting Accuracy  % Goals-to-shots  Total shots (inc. Blocked)  \
# 0              0.519             0.160                          32
# 1              0.419             0.129                          39
# 2              0.500             0.200                          27
# 3              0.500             0.172                          40
# 4              0.379             0.065                          65
#
#    Hit Woodwork  Penalty goals  Penalties not scored  ...  Saves made  \
# 0             0              0                     0  ...          13
# ...

# %%
#Step 4
euro12['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
#step 5
euro12['Team'].count()
# Out:
# 16

# %%
#Step 6
len(euro12.columns)
# Out:
# 35

# %%
#step 7
discipline=euro12[['Team','Yellow Cards','Red Cards']]

# %%
#Step 8
discipline.head()
# Out:
#              Team  Yellow Cards  Red Cards
# 0         Croatia             9          0
# 1  Czech Republic             7          0
# 2         Denmark             4          0
# 3         England             5          0
# 4          France             6          0

# %%
discipline.sort_values(by=['Red Cards','Yellow Cards'])
# Out:
#                    Team  Yellow Cards  Red Cards
# 2               Denmark             4          0
# 5               Germany             4          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 4                France             6          0
# 12               Russia             6          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 0               Croatia             9          0
# 13                Spain            11          0
# 10             Portugal            12          0
# 7                 Italy            16          0
# 11  Republic of Ireland             6          1
# 9                Poland             7          1
# 6                Greece             9          1

# %%
#Step 9
discipline.groupby('Team').mean()['Yellow Cards']
# Out:
# Team
# Croatia                 9.0
# Czech Republic          7.0
# Denmark                 4.0
# England                 5.0
# France                  6.0
# Germany                 4.0
# Greece                  9.0
# Italy                  16.0
# Netherlands             5.0
# Poland                  7.0
# Portugal               12.0
# Republic of Ireland     6.0
# Russia                  6.0
# Spain                  11.0
# Sweden                  7.0
# Ukraine                 5.0
# Name: Yellow Cards, dtype: float64

# %%
#Step 10
euro12[euro12['Goals']>6]['Team']
# Out:
# 5     Germany
# 13      Spain
# Name: Team, dtype: object

# %%
#Step 11
euro12[euro12['Team'].str.startswith('G')]['Team']
# Out:
# 5    Germany
# 6     Greece
# Name: Team, dtype: object

# %%
#Step 12
euro12.iloc[:, : 7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#step 13
euro12.iloc[ : , : -3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#Step 14
euro12.loc[euro12.Team.isin(['England','Italy','Russia']),
         'Shooting Accuracy']
# Out:
# 3     0.500
# 7     0.430
# 12    0.225
# Name: Shooting Accuracy, dtype: float64

# %% [markdown]
# #question3 answers

# %%
#Step 1 already imported libraries above 
#Step 2
first=pd.Series(np.random.randint(1,4,100))
second=pd.Series(np.random.randint(1,3,100))
third=pd.Series(np.random.randint(10000,30000,100))

# %%
#Step 3
result=pd.concat([first,second,third],axis=1)
datafrm=pd.DataFrame(result)

# %%
datafrm
# Out:
#     0  1      2
# 0   3  1  15585
# 1   2  1  19421
# 2   3  2  25362
# 3   2  1  22386
# 4   3  1  24669
# .. .. ..    ...
# 95  1  2  28626
# 96  3  1  16667
# 97  1  1  12248
# 98  3  1  24588
# 99  2  2  27759
#
# [100 rows x 3 columns]

# %%
#step 4
datafrm.rename(columns={0:'bedrs',1:'bathrs',2:'price_sqr_meter'},inplace=True)

# %%
print(datafrm)
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       3       1            15585
# 1       2       1            19421
# 2       3       2            25362
# 3       2       1            22386
# 4       3       1            24669
# ..    ...     ...              ...
# 95      1       2            28626
# 96      3       1            16667
# 97      1       1            12248
# 98      3       1            24588
# 99      2       2            27759
#
# [100 rows x 3 columns]

# %%
#Step 5
bigcolumn=pd.concat([first,second,third])
bigcolumn
# Out:
# 0         3
# 1         2
# 2         3
# 3         2
# 4         3
#       ...
# 95    28626
# 96    16667
# 97    12248
# 98    24588
# 99    27759
# Length: 300, dtype: int32

# %%
#Step 6
bigcolumn.reset_index(drop=True)
# Out:
# 0          3
# 1          2
# 2          3
# 3          2
# 4          3
#        ...
# 295    28626
# 296    16667
# 297    12248
# 298    24588
# 299    27759
# Length: 300, dtype: int32

# %% [markdown]
# #question 4 answers

# %%
#Step 1 already completed.pls refer above
#Step 2

data = pd.read_csv(r"C:\Users\aryas\Downloads\wind.csv")

# %%
data
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# ...

# %%
data["Datetime"] = pd.to_datetime(data[["Yr","Mo","Dy"]].astype(str).agg('-'.join, axis=1))
data=data.drop(columns=["Yr","Mo","Dy"])

# %%
data["Datetime"]
# Out:
# 0      2061-01-01
# 1      2061-01-02
# 2      2061-01-03
# 3      2061-01-04
# 4      2061-01-05
#           ...
# 6569   1978-12-27
# 6570   1978-12-28
# 6571   1978-12-29
# 6572   1978-12-30
# 6573   1978-12-31
# Name: Datetime, Length: 6574, dtype: datetime64[ns]

# %%
#step 4
data["str"]=data["Datetime"].astype(str).str.slice(0,4)
data["str"]=data["str"].astype(int)
data["str"]=data["str"].apply(lambda x: x-100 if x > 2023 else x)

# %%
data["DateTime"]=data["str"].astype(str) + data["Datetime"].astype(str).str.slice(4,10)

# %%
data.drop (["Datetime","str"],axis=1,inplace=True)

# %%
#step 5
data["DateTime"].astype("datetime64[ns]")
# Out:
# 0      1961-01-01
# 1      1961-01-02
# 2      1961-01-03
# 3      1961-01-04
# 4      1961-01-05
#           ...
# 6569   1978-12-27
# 6570   1978-12-28
# 6571   1978-12-29
# 6572   1978-12-30
# 6573   1978-12-31
# Name: DateTime, Length: 6574, dtype: datetime64[ns]

# %%
data.set_index("DateTime",inplace=True)

# %%
#step 6
data.isnull().sum().sum()
# Out:
# 31

# %%
#step 7
data.notnull().sum().sum()
# Out:
# 78857

# %%
#step 8
data.mean().mean()
# Out:
# 10.227982360836924

# %%
#step 9
x=pd.Series(data.min())
y=pd.Series(data.max())
z=pd.Series(data.mean())
sd=pd.Series(data.std())

# %%
l=pd.concat([x,y,z,sd],axis=1).transpose()

# %%
loc_stats=pd.DataFrame(l)

# %%
loc_stats
# Out:
#          RPT        VAL        ROS        KIL        SHA        BIR  \
# 0   0.670000   0.210000   1.500000   0.000000   0.130000   0.000000
# 1  35.800000  33.370000  33.840000  28.460000  37.540000  26.160000
# 2  12.362987  10.644314  11.660526   6.306468  10.455834   7.092254
# 3   5.618413   5.267356   5.008450   3.605811   4.936125   3.968683
#
#          DUB        CLA        MUL        CLO        BEL        MAL
# 0   0.000000   0.000000   0.000000   0.040000   0.130000   0.670000
# 1  30.370000  31.080000  25.880000  28.210000  42.380000  42.540000
# 2   9.797343   8.495053   8.493590   8.707332  13.121007  15.599079
# 3   4.977555   4.499449   4.166872   4.503954   5.835037   6.699794

# %%
#step 10
x=pd.Series(data.min(axis=1),name="mean")
y=pd.Series(data.max(axis=1),name="max")
z=pd.Series(data.mean(axis=1),name="min")
sd=pd.Series(data.std(axis=1),name="std dev")

# %%
df=pd.merge(x,y,left_index=True,right_index=True)
df1=pd.merge(z,sd,left_index=True,right_index=True)
day_stats=df.join(df1)
day_stats
# Out:
#             mean    max        min   std dev
# DateTime
# 1961-01-01  9.29  18.50  13.018182  2.808875
# 1961-01-02  6.50  17.54  11.336364  3.188994
# 1961-01-03  6.17  18.50  11.641818  3.681912
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356
# ...          ...    ...        ...       ...
# 1978-12-27  8.08  40.08  16.708333  7.868076
# 1978-12-28  5.00  41.46  15.150000  9.687857
# 1978-12-29  8.71  29.58  14.890000  5.756836
# 1978-12-30  9.13  28.79  15.367500  5.540437
# 1978-12-31  9.59  27.29  15.402500  5.702483
#
# [6574 rows x 4 columns]

# %%
#Step 11
d=data.reset_index()
d["DateTime"]=d["DateTime"].apply(pd.to_datetime)

# %%
d.set_index("DateTime",inplace=True)

# %%
jan=d[d.index.month == 1]
jan.mean()
# Out:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %%
#step 12
print(d.resample('Y').mean())
# Out:
#                   RPT        VAL        ROS       KIL        SHA       BIR  \
# DateTime
# 1961-12-31  12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962-12-31  12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963-12-31  12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964-12-31  12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965-12-31  12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966-12-31  13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967-12-31  12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968-12-31  11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969-12-31  11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970-12-31  12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 1971-12-31  11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
# ...

# %%
#Step 13
print(d.resample('M').mean())
# Out:
#                   RPT        VAL        ROS       KIL        SHA        BIR  \
# DateTime
# 1961-01-31  14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# 1961-02-28  16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# 1961-03-31  10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
# 1961-04-30  10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05-31   9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
# ...               ...        ...        ...       ...        ...        ...
# 1978-08-31   9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09-30  10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10-31   9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11-30  16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
# 1978-12-31  16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
# ...

# %%
#Step 14
print(d.resample('W').mean())
# Out:
#                   RPT        VAL        ROS        KIL        SHA        BIR  \
# DateTime
# 1961-01-01  15.040000  14.960000  13.170000   9.290000        NaN   9.870000
# 1961-01-08  13.541429  11.486667  10.487143   6.417143   9.474286   6.435714
# 1961-01-15  12.468571   8.967143  11.958571   4.630000   7.351429   5.072857
# 1961-01-22  13.204286   9.862857  12.982857   6.328571   8.966667   7.417143
# 1961-01-29  19.880000  16.141429  18.225714  12.720000  17.432857  14.828571
# ...               ...        ...        ...        ...        ...        ...
# 1978-12-03  14.934286  11.232857  13.941429   5.565714  10.215714   8.618571
# 1978-12-10  20.740000  19.190000  17.034286   9.777143  15.287143  12.774286
# 1978-12-17  16.758571  14.692857  14.987143   6.917143  11.397143   7.272857
# 1978-12-24  11.155714   8.008571  13.172857   4.004286   7.825714   6.290000
# 1978-12-31  14.951429  11.801429  16.035714   6.507143   9.660000   8.620000
#
# ...

# %%
#Step 15
y=d[d.index.year==1961]
y1=d.resample('W').mean().apply(lambda x: x.describe())

# %%
y1
# Out:
#               RPT         VAL         ROS         KIL         SHA         BIR  \
# count  940.000000  940.000000  940.000000  940.000000  939.000000  940.000000
# mean    12.365304   10.647725   11.661255    6.309334   10.455607    7.094787
# std      3.466600    3.372501    2.840361    2.186432    3.146715    2.556633
# min      3.874286    2.452857    4.901429    1.447143    2.775714    1.382857
# 25%      9.884286    8.277857    9.613929    4.742857    8.248571    5.211071
# 50%     12.291429   10.486429   11.490000    6.165714   10.254286    6.933571
# 75%     14.547143   12.757857   13.457143    7.584286   12.627143    8.842500
# max     24.010000   23.715714   21.384286   14.517143   22.897143   16.010000
#
#               DUB         CLA         MUL         CLO         BEL         MAL
# count  940.000000  940.000000  940.000000  940.000000  940.000000  940.000000
# mean     9.801271    8.496123    8.496452    8.710639   13.125912   15.597171
# ...

# %% [markdown]
# #Question 5 answers

# %%
#step 1 already done
#step 2 & 3
chipo=pd.read_csv(r"C:\Users\aryas\Documents\chipo.csv")

# %%
#step 4
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# ...

# %%
#step 5
len(chipo)
# Out:
# 4622

# %%
#step 6
len(chipo.columns)
# Out:
# 5

# %%
#step 7
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#step 8
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
#step 9
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
#step 9
chipo.item_name.value_counts().head(1)
# Out:
# Chicken Bowl    726
# Name: item_name, dtype: int64

# %%
#step 10
chipo.item_name.value_counts()[0]
# Out:
# 726

# %%
#step 11
chipo.choice_description.value_counts().head(1)
# Out:
# [Diet Coke]    134
# Name: choice_description, dtype: int64

# %%
#step 12
len(chipo.item_name.unique())
# Out:
# 50

# %%
#step 13
chipo["item_price"].astype(float)
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
chipo["item_price"].dtype
# Out:
# dtype('float64')

# %%
chipo["item_price"].apply(lambda x : pd.to_numeric(x))
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
#step 14
d=chipo["item_price"]*chipo["quantity"]
d.sum()
# Out:
# 39237.02

# %%
#Step 15
l=len(chipo["order_id"].unique())
l
# Out:
# 1834

# %%
#Step 16
d.sum()/l
# Out:
# 21.39423118865867

# %%
#step 17
len(chipo["item_name"].unique())
# Out:
# 50

# %% [markdown]
# #Question 6 answers

# %%
mrg=pd.read_csv(r"C:\Users\aryas\Downloads\us-marriages-divorces-1867-2014.csv")

# %%
import matplotlib.pyplot as plt

# %%
mrg.head()
# Out:
#    Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0  1867   357000.0   10000.0    36970000                 9.7
# 1  1868   345000.0   10000.0    37885000                 9.1
# 2  1869   348000.0   11000.0    38870000                 9.0
# 3  1870   352000.0   11000.0    39905000                 8.8
# 4  1871   359000.0   12000.0    41010000                 8.8
#
#    Divorces_per_1000
# 0                0.3
# 1                0.3
# 2                0.3
# 3                0.3
# 4                0.3

# %%
axisVar=mrg.plot(x='Year',y=['Marriages_per_1000','Divorces_per_1000'])
axisVar.set_xlabel('Year')
axisVar.set_ylabel('Marraiges & Divorcers per capita')
# Out:
# Text(0, 0.5, 'Marraiges & Divorcers per capita')

# %% [markdown]
# #Question 7

# %%
samp=mrg[(mrg['Year'].isin([1900,1950,2000]))]
res=samp.plot.bar(x='Year',y=['Marriages_per_1000','Divorces_per_1000'],xlabel='Year',ylabel='Marriages & Divorcers per capita')

# %% [markdown]
# #Question 8 answers

# %%
actors=pd.read_csv(r"C:\Users\aryas\Downloads\actor_kill_counts.csv")

# %%
actors.head()
# Out:
#                    Actor  Count
# 0  Arnold Schwarzenegger    369
# 1           Chow Yun-Fat    295
# 2         Clint Eastwood    207
# 3             Clive Owen    194
# 4         Dolph Lundgren    239

# %%
actors.shape
# Out:
# (10, 2)

# %%
k=actors.set_index('Actor').sort_values('Count').plot(kind='barh')
k.set_xlabel('Kill Count')
# Out:
# Text(0.5, 0, 'Kill Count')

# %% [markdown]
# #Question 9

# %%
romanEm=actor=pd.read_csv(r"C:\Users\aryas\Downloads\roman-emperor-reigns.csv")

# %%
romanEm.head()
# Out:
#     Emperor  Length_of_Reign         Cause_of_Death
# 0  Augustus            40.58  Possibly assassinated
# 1  Tiberius            22.50  Possibly assassinated
# 2  Caligula             4.83           Assassinated
# 3  Claudius            13.75  Possibly assassinated
# 4      Nero            13.67                Suicide

# %%
roman1=romanEm[(romanEm['Cause_of_Death']=='Assassinated')].set_index('Emperor')
rm=roman1.plot(kind='pie',x='Emperor',y='Length_of_Reign',figsize=(13,13),autopct='%1.5f%%',fontsize='x-large').legend(bbox_to_anchor=(1,1))

# %%
#Question 10
import seaborn as sns

# %%
rev=pd.read_csv(r"C:\Users\aryas\Downloads\arcade-revenue-vs-cs-doctorates.csv")

# %%
rev.head()
# Out:
#    Year  Total Arcade Revenue (billions)  \
# 0  2000                            1.196
# 1  2001                            1.176
# 2  2002                            1.269
# 3  2003                            1.240
# 4  2004                            1.307
#
#    Computer Science Doctorates Awarded (US)
# 0                                       861
# 1                                       830
# 2                                       809
# 3                                       867
# 4                                       948

# %%
sns.lmplot('Total Arcade Revenue (billions)', 'Computer Science Doctorates Awarded (US)', data=rev, hue='Year', fit_reg=False)
# Out:
# C:\Users\aryas\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
